# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
pd.set_option('display.max_rows', 500)

# %%
dates = ['2024-06-10', '2024-06-11', '2024-06-12', '2024-06-13', '2024-06-14', '2024-06-17', '2024-06-18', '2024-06-19', '2024-06-20', '2024-06-21']
cleaned = []

# %%
class Cleaner:
    
    def __init__(self, date):
        self.lob = pd.read_table(f"../../txt_files/UoB_Set01_{date}LOBs.txt")
        
    def extract_info(self):
        
        # extract timestamps
        pattern = r'(\d+.+?),'
        timestamps = self.lob.iloc[:,0].str.extract(pattern)
        self.lob['Timestamps'] = timestamps
        
        # extract asks
        pattern1 = r"'ask', (\[\[(?:\d+,\s*\d+)\]\])"
        pattern2 = r"'ask', (\[(\[(?:\d+,\s*)+\d+\], )+\[(?:\d+,\s*)+\d+\]\])"
        asks1 = self.lob.iloc[:,0].str.findall(pattern1)
        asks2 = self.lob.iloc[:,0].str.findall(pattern2)
        ask_list = []
        for ask in asks2:
            if len(ask) == 0:
                ask_list.append('[]')
            else:
                ask_list.append(ask[0][0])
        for i in range(len(ask_list)):
            if ask_list[i] == '[]':
                if asks1[i] != []:
                    ask_list[i] = asks1[i][0]
        self.lob['Asks'] = ask_list
        
        # extract bids
        pattern1 = r"'bid', (\[\[(?:\d+,\s*\d+)\]\])"
        pattern2 = r"'bid', (\[(\[(?:\d+,\s*)+\d+\], )+\[(?:\d+,\s*)+\d+\]\])"
        bids1 = self.lob.iloc[:,0].str.findall(pattern1)
        bids2 = self.lob.iloc[:,0].str.findall(pattern2)
        bid_list = []
        for bid in bids2:
            if len(bid) == 0:
                bid_list.append('[]')
            else:
                bid_list.append(bid[0][0])
        for i in range(len(bid_list)):
            if bid_list[i] == '[]':
                if bids1[i] != []:
                    bid_list[i] = bids1[i][0]
        self.lob['Bids'] = bid_list
        
        # cleaning
        self.lob = self.lob.drop(columns="[0.000, Exch0, [['bid', []], ['ask', []]]]")
        new_row = pd.DataFrame({'Timestamps':'0.000', 'Bids':'[]', 'Asks':'[]'}, index=[0])
        self.lob = pd.concat([new_row,self.lob.loc[:]]).reset_index(drop=True)
        
        return self.lob

# %%
class apply_functions:
    
    def ba(self, x):
        try:
            return x[0][0]
        except:
            return np.nan
        
    def vol_ba(self, x):
        try:
            return x[0][1]
        except:
            return 0
    
    def dW(self, x, df):
        if df.b[x.index.start] == df.b[x.index.stop-1]:
            return x.iloc[-1] - x.iloc[0]
        if df.b[x.index.stop-1] > df.b[x.index.start]:
            return x.iloc[-1]
        if df.b[x.index.stop-1] < df.b[x.index.start]:
            return -x.iloc[0]
        else:
            return np.NaN

    def dV(self, x, df):
        if df.a[x.index.start] == df.a[x.index.stop-1]:
            return x.iloc[-1] - x.iloc[0]
        if df.a[x.index.stop-1] > df.a[x.index.start]:
            return -x.iloc[0]
        if df.a[x.index.stop-1] < df.a[x.index.start]:
            return x.iloc[-1]
        else:
            return np.NaN
        
    def count_vol(self, x):
        count = 0
        for entry in x:
            count += entry[1]
        return count
    
    def get_signal(self, x, df):
        if df.b[x.index[0]] >= df.a[x.index[-1]] + 2:  # margin of safety = 2 here
            return 2
        if df.a[x.index[0]] <= df.b[x.index[-1]] - 2:  # margin of safety = 2 here also
            return 0
        else:
            return 1

# %%
class Processor(apply_functions):
    
    def __init__(self, lob):
        self.lob = lob
        self.lob_r = None
        
    def make_arrays(self):
        self.lob.Bids = self.lob.Bids.apply(lambda x: ast.literal_eval(str(x)))
        self.lob.Asks = self.lob.Asks.apply(lambda x: ast.literal_eval(str(x)))
        self.lob.Timestamps = self.lob.Timestamps.apply(lambda x: float(x))
        self.lob.Bids = self.lob.Bids.apply(lambda x: np.array(x))
        self.lob.Asks = self.lob.Asks.apply(lambda x: np.array(x))
        
    def add_b_a(self):
        self.lob['b'] = self.lob.Bids.apply(self.ba)
        self.lob['a'] = self.lob.Asks.apply(self.ba)
        self.lob['s'] = self.lob['a'].subtract(self.lob.b)
        
    def add_m(self):
        self.lob['m'] = self.lob['b'] + ((self.lob['a'] - self.lob['b']) / 2)
    
    def make_index_delta(self):
        td = pd.to_timedelta(self.lob['Timestamps'],'s')
        self.lob = self.lob.set_index(td)
    
    def get_vol_at_a_b(self):
        self.lob['vol_b'] = self.lob.Bids.apply(self.vol_ba)
        self.lob['vol_a'] = self.lob.Asks.apply(self.vol_ba)
    
    def add_OFI_req(self):
        self.lob = self.lob.reset_index(drop=True)
        self.lob['dW'] = self.lob.vol_b.rolling(window=2).apply(lambda x: self.dW(x, self.lob))
        self.lob['dV'] = self.lob.vol_a.rolling(window=2).apply(lambda x: self.dV(x, self.lob))
        self.lob['e'] = self.lob['dW'] - self.lob['dV']
    
    def add_OFI(self, interval):
        td = pd.to_timedelta(self.lob['Timestamps'],'s')
        self.lob = self.lob.set_index(td)
        self.lob.loc[:, f'OFI{interval}'] = self.lob['e'].rolling(interval).sum()
    
    def add_volume_metrics(self):
        self.lob['all_vol_b'] = self.lob.Bids.apply(lambda x: self.count_vol(x))
        self.lob['all_vol_a'] = self.lob.Asks.apply(lambda x: self.count_vol(x))
        self.lob['all_vol_diff'] = self.lob['all_vol_b'] - self.lob['all_vol_a']
        self.lob['OBI'] = (self.lob['vol_b'] - self.lob['vol_a']) / (self.lob['vol_b'] + self.lob['vol_a'])
    
    def add_signal(self, interval):
        time = interval
        self.lob_r = self.lob[::-1]
        self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
        self.lob = self.lob.join(self.lob_r[f'signal_{interval}'])

# %%
for date in dates:
    x = Cleaner(date)
    cleaned.append(x.extract_info())

# %%
len(cleaned)
# Out:
# 10

# %%
processed = []

# %%
for i, df in enumerate(cleaned):
    x = Processor(df)
    x.make_arrays()
    x.add_b_a()
    x.add_m()
    x.make_index_delta()
    x.get_vol_at_a_b()
    x.add_OFI_req()
    x.add_volume_metrics()
    for interval in ['5s', '10s', '20s', '30s', '45s', '60s']:
        x.add_OFI(interval)
    for interval in ['5s', '10s', '20s', '30s', '45s', '60s']:
        x.add_signal(interval)
    processed.append(x.lob)
    print('finished', i)
    display(x.lob)
# Out:
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 0
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:02.077000       2.077
# 0 days 00:00:02.356000       2.356
# 0 days 00:00:02.697000       2.697
# 0 days 00:00:02.945000       2.945
# ...                            ...
# 0 days 08:29:59.604000   30599.604
# 0 days 08:29:59.759000   30599.759
# 0 days 08:29:59.790000   30599.790
# 0 days 08:29:59.852000   30599.852
# 0 days 08:29:59.945000   30599.945
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:02.077000                                                 []
# 0 days 00:00:02.356000                                          [[47, 1]]
# 0 days 00:00:02.697000                                 [[93, 3], [47, 1]]
# 0 days 00:00:02.945000                        [[94, 4], [93, 3], [47, 1]]
# ...                                                                   ...
# 0 days 08:29:59.604000  [[106, 8], [105, 1], [104, 4], [103, 16], [101...
# 0 days 08:29:59.759000  [[106, 8], [105, 1], [104, 4], [103, 16], [101...
# 0 days 08:29:59.790000  [[109, 3], [106, 8], [105, 1], [104, 4], [103,...
# 0 days 08:29:59.852000  [[109, 2], [106, 8], [105, 1], [104, 4], [103,...
# 0 days 08:29:59.945000  [[109, 2], [108, 1], [106, 8], [105, 1], [104,...
#
#                                                   Asks      b      a      s  \
# Timestamps
# 0 days 00:00:00                                     []    NaN    NaN    NaN
# 0 days 00:00:02.077000                      [[100, 2]]    NaN  100.0    NaN
# 0 days 00:00:02.356000                      [[100, 2]]   47.0  100.0   53.0
# 0 days 00:00:02.697000                      [[100, 2]]   93.0  100.0    7.0
# 0 days 00:00:02.945000                      [[100, 2]]   94.0  100.0    6.0
# ...                                                ...    ...    ...    ...
# 0 days 08:29:59.604000  [[246, 1], [247, 4], [520, 4]]  106.0  246.0  140.0
# 0 days 08:29:59.759000  [[246, 1], [520, 4], [734, 4]]  106.0  246.0  140.0
# 0 days 08:29:59.790000  [[246, 1], [520, 4], [734, 4]]  109.0  246.0  137.0
# 0 days 08:29:59.852000  [[246, 1], [520, 4], [734, 4]]  109.0  246.0  137.0
# 0 days 08:29:59.945000  [[246, 1], [520, 4], [734, 4]]  109.0  246.0  137.0
#
#                             m  vol_b  vol_a   dW  ...  OFI20s  OFI30s  OFI45s  \
# Timestamps                                        ...
# 0 days 00:00:00           NaN      0      0  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.077000    NaN      0      2  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.356000   73.5      1      2  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.697000   96.5      3      2  3.0  ...     3.0     3.0     3.0
# 0 days 00:00:02.945000   97.0      4      2  4.0  ...     7.0     7.0     7.0
# ...                       ...    ...    ...  ...  ...     ...     ...     ...
# 0 days 08:29:59.604000  176.0      8      1  0.0  ...  -194.0  -224.0  -243.0
# 0 days 08:29:59.759000  176.0      8      1  0.0  ...  -194.0  -224.0  -243.0
# 0 days 08:29:59.790000  177.5      3      1  3.0  ...  -191.0  -221.0  -240.0
# 0 days 08:29:59.852000  177.5      2      1 -1.0  ...  -192.0  -222.0  -241.0
# 0 days 08:29:59.945000  177.5      2      1  0.0  ...  -192.0  -222.0  -241.0
#
#                         OFI60s  signal_5s  signal_10s  signal_20s  signal_30s  \
# Timestamps
# 0 days 00:00:00            NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.077000     NaN        2.0         2.0         1.0         1.0
# 0 days 00:00:02.356000     NaN        2.0         2.0         1.0         1.0
# 0 days 00:00:02.697000     3.0        2.0         2.0         1.0         1.0
# 0 days 00:00:02.945000     7.0        2.0         2.0         1.0         1.0
# ...                        ...        ...         ...         ...         ...
# 0 days 08:29:59.604000  -269.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.759000  -269.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.790000  -266.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.852000  -267.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.945000  -266.0        1.0         1.0         1.0         1.0
#
#                         signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0
# 0 days 00:00:02.077000         1.0         1.0
# 0 days 00:00:02.356000         1.0         1.0
# 0 days 00:00:02.697000         1.0         1.0
# 0 days 00:00:02.945000         1.0         1.0
# ...                            ...         ...
# 0 days 08:29:59.604000         1.0         1.0
# 0 days 08:29:59.759000         1.0         1.0
# 0 days 08:29:59.790000         1.0         1.0
# 0 days 08:29:59.852000         1.0         1.0
# 0 days 08:29:59.945000         1.0         1.0
#
# [321766 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 1
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:02.883000       2.883
# 0 days 00:00:04.154000       4.154
# 0 days 00:00:04.278000       4.278
# 0 days 00:00:04.743000       4.743
# ...                            ...
# 0 days 08:29:59.666000   30599.666
# 0 days 08:29:59.821000   30599.821
# 0 days 08:29:59.852000   30599.852
# 0 days 08:29:59.883000   30599.883
# 0 days 08:29:59.976000   30599.976
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:02.883000                                         [[82, 11]]
# 0 days 00:00:04.154000                                [[85, 2], [82, 11]]
# 0 days 00:00:04.278000                                [[85, 2], [69, 11]]
# 0 days 00:00:04.743000                       [[85, 2], [82, 1], [69, 11]]
# ...                                                                   ...
# 0 days 08:29:59.666000  [[110, 1], [108, 7], [104, 4], [103, 4], [102,...
# 0 days 08:29:59.821000  [[110, 1], [108, 7], [104, 4], [103, 4], [102,...
# 0 days 08:29:59.852000  [[110, 1], [108, 7], [104, 4], [103, 4], [102,...
# 0 days 08:29:59.883000  [[110, 1], [108, 7], [104, 4], [103, 4], [102,...
# 0 days 08:29:59.976000  [[110, 1], [108, 7], [104, 4], [103, 4], [102,...
#
#                                                   Asks      b      a      s  \
# Timestamps
# 0 days 00:00:00                                     []    NaN    NaN    NaN
# 0 days 00:00:02.883000                              []   82.0    NaN    NaN
# 0 days 00:00:04.154000                              []   85.0    NaN    NaN
# 0 days 00:00:04.278000                              []   85.0    NaN    NaN
# 0 days 00:00:04.743000                              []   85.0    NaN    NaN
# ...                                                ...    ...    ...    ...
# 0 days 08:29:59.666000  [[565, 1], [676, 4], [771, 5]]  110.0  565.0  455.0
# 0 days 08:29:59.821000  [[507, 1], [676, 4], [771, 5]]  110.0  507.0  397.0
# 0 days 08:29:59.852000  [[507, 1], [676, 4], [771, 5]]  110.0  507.0  397.0
# 0 days 08:29:59.883000  [[507, 1], [676, 4], [771, 5]]  110.0  507.0  397.0
# 0 days 08:29:59.976000  [[507, 1], [676, 4], [771, 5]]  110.0  507.0  397.0
#
#                             m  vol_b  vol_a   dW  ...  OFI20s  OFI30s  OFI45s  \
# Timestamps                                        ...
# 0 days 00:00:00           NaN      0      0  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.883000    NaN     11      0  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:04.154000    NaN      2      0  2.0  ...     NaN     NaN     NaN
# 0 days 00:00:04.278000    NaN      2      0  0.0  ...     NaN     NaN     NaN
# 0 days 00:00:04.743000    NaN      2      0  0.0  ...     NaN     NaN     NaN
# ...                       ...    ...    ...  ...  ...     ...     ...     ...
# 0 days 08:29:59.666000  337.5      1      1  0.0  ...  -118.0  -160.0  -200.0
# 0 days 08:29:59.821000  308.5      1      1  0.0  ...  -115.0  -157.0  -201.0
# 0 days 08:29:59.852000  308.5      1      1  0.0  ...  -115.0  -157.0  -201.0
# 0 days 08:29:59.883000  308.5      1      1  0.0  ...  -115.0  -157.0  -201.0
# 0 days 08:29:59.976000  308.5      1      1  0.0  ...  -115.0  -153.0  -201.0
#
#                         OFI60s  signal_5s  signal_10s  signal_20s  signal_30s  \
# Timestamps
# 0 days 00:00:00            NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.883000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:04.154000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:04.278000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:04.743000     NaN        1.0         1.0         1.0         1.0
# ...                        ...        ...         ...         ...         ...
# 0 days 08:29:59.666000  -367.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.821000  -368.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.852000  -368.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.883000  -368.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.976000  -368.0        1.0         1.0         1.0         1.0
#
#                         signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0
# 0 days 00:00:02.883000         1.0         1.0
# 0 days 00:00:04.154000         1.0         1.0
# 0 days 00:00:04.278000         1.0         1.0
# 0 days 00:00:04.743000         1.0         1.0
# ...                            ...         ...
# 0 days 08:29:59.666000         1.0         1.0
# 0 days 08:29:59.821000         1.0         1.0
# 0 days 08:29:59.852000         1.0         1.0
# 0 days 08:29:59.883000         1.0         1.0
# 0 days 08:29:59.976000         1.0         1.0
#
# [324042 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 2
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:00.806000       0.806
# 0 days 00:00:00.868000       0.868
# 0 days 00:00:01.209000       1.209
# 0 days 00:00:01.829000       1.829
# ...                            ...
# 0 days 08:29:59.666000   30599.666
# 0 days 08:29:59.697000   30599.697
# 0 days 08:29:59.821000   30599.821
# 0 days 08:29:59.852000   30599.852
# 0 days 08:29:59.976000   30599.976
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:00.806000                                          [[89, 4]]
# 0 days 00:00:00.868000                                          [[13, 4]]
# 0 days 00:00:01.209000                                          [[13, 4]]
# 0 days 00:00:01.829000                               [[102, 11], [13, 4]]
# ...                                                                   ...
# 0 days 08:29:59.666000  [[111, 1], [104, 4], [102, 9], [79, 1], [78, 7...
# 0 days 08:29:59.697000  [[111, 1], [104, 4], [102, 9], [79, 1], [78, 7...
# 0 days 08:29:59.821000  [[111, 1], [108, 4], [104, 4], [102, 9], [79, ...
# 0 days 08:29:59.852000  [[111, 1], [108, 4], [104, 4], [102, 9], [78, ...
# 0 days 08:29:59.976000  [[108, 3], [104, 4], [102, 9], [78, 7], [77, 1...
#
#                                                             Asks      b  \
# Timestamps
# 0 days 00:00:00                                               []    NaN
# 0 days 00:00:00.806000                                        []   89.0
# 0 days 00:00:00.868000                                        []   13.0
# 0 days 00:00:01.209000                                [[116, 1]]   13.0
# 0 days 00:00:01.829000                                [[116, 1]]  102.0
# ...                                                          ...    ...
# 0 days 08:29:59.666000  [[213, 2], [302, 3], [512, 5], [774, 5]]  111.0
# 0 days 08:29:59.697000  [[213, 2], [302, 3], [512, 5], [774, 5]]  111.0
# 0 days 08:29:59.821000  [[213, 2], [302, 3], [512, 5], [774, 5]]  111.0
# 0 days 08:29:59.852000  [[213, 2], [302, 3], [512, 5], [774, 5]]  111.0
# 0 days 08:29:59.976000            [[302, 3], [512, 5], [774, 5]]  108.0
#
#                             a      s      m  vol_b  vol_a    dW  ...  OFI20s  \
# Timestamps                                                       ...
# 0 days 00:00:00           NaN    NaN    NaN      0      0   NaN  ...     NaN
# 0 days 00:00:00.806000    NaN    NaN    NaN      4      0   NaN  ...     NaN
# 0 days 00:00:00.868000    NaN    NaN    NaN      4      0  -4.0  ...     NaN
# 0 days 00:00:01.209000  116.0  103.0   64.5      4      1   0.0  ...     NaN
# 0 days 00:00:01.829000  116.0   14.0  109.0     11      1  11.0  ...    11.0
# ...                       ...    ...    ...    ...    ...   ...  ...     ...
# 0 days 08:29:59.666000  213.0  102.0  162.0      1      2   0.0  ...  -207.0
# 0 days 08:29:59.697000  213.0  102.0  162.0      1      2   0.0  ...  -207.0
# 0 days 08:29:59.821000  213.0  102.0  162.0      1      2   0.0  ...  -207.0
# 0 days 08:29:59.852000  213.0  102.0  162.0      1      2   0.0  ...  -207.0
# 0 days 08:29:59.976000  302.0  194.0  205.0      3      3  -1.0  ...  -206.0
#
#                         OFI30s  OFI45s  OFI60s  signal_5s  signal_10s  \
# Timestamps
# 0 days 00:00:00            NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:00.806000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:00.868000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:01.209000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:01.829000    11.0    11.0    11.0        1.0         1.0
# ...                        ...     ...     ...        ...         ...
# 0 days 08:29:59.666000  -253.0  -334.0  -391.0        1.0         1.0
# 0 days 08:29:59.697000  -253.0  -334.0  -391.0        1.0         1.0
# 0 days 08:29:59.821000  -253.0  -334.0  -391.0        1.0         1.0
# 0 days 08:29:59.852000  -252.0  -334.0  -391.0        1.0         1.0
# 0 days 08:29:59.976000  -251.0  -333.0  -390.0        1.0         1.0
#
#                         signal_20s  signal_30s  signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0         1.0         1.0
# 0 days 00:00:00.806000         1.0         1.0         1.0         1.0
# 0 days 00:00:00.868000         1.0         1.0         1.0         1.0
# 0 days 00:00:01.209000         1.0         1.0         1.0         1.0
# 0 days 00:00:01.829000         1.0         1.0         1.0         1.0
# ...                            ...         ...         ...         ...
# 0 days 08:29:59.666000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.697000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.821000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.852000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.976000         1.0         1.0         1.0         1.0
#
# [319867 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 3
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:01.333000       1.333
# 0 days 00:00:02.325000       2.325
# 0 days 00:00:02.387000       2.387
# 0 days 00:00:02.728000       2.728
# ...                            ...
# 0 days 08:29:59.511000   30599.511
# 0 days 08:29:59.604000   30599.604
# 0 days 08:29:59.697000   30599.697
# 0 days 08:29:59.728000   30599.728
# 0 days 08:29:59.852000   30599.852
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:01.333000                                                 []
# 0 days 00:00:02.325000                                                 []
# 0 days 00:00:02.387000                                                 []
# 0 days 00:00:02.728000                                                 []
# ...                                                                   ...
# 0 days 08:29:59.511000  [[106, 5], [104, 12], [103, 2], [102, 5], [101...
# 0 days 08:29:59.604000  [[106, 5], [104, 12], [103, 2], [102, 5], [101...
# 0 days 08:29:59.697000  [[106, 5], [104, 12], [103, 2], [102, 5], [101...
# 0 days 08:29:59.728000  [[106, 5], [104, 12], [103, 2], [102, 5], [101...
# 0 days 08:29:59.852000  [[106, 5], [105, 1], [104, 12], [103, 2], [102...
#
#                                                   Asks      b      a      s  \
# Timestamps
# 0 days 00:00:00                                     []    NaN    NaN    NaN
# 0 days 00:00:01.333000                      [[261, 5]]    NaN  261.0    NaN
# 0 days 00:00:02.325000            [[260, 3], [261, 5]]    NaN  260.0    NaN
# 0 days 00:00:02.387000            [[165, 5], [260, 3]]    NaN  165.0    NaN
# 0 days 00:00:02.728000  [[165, 5], [177, 1], [260, 3]]    NaN  165.0    NaN
# ...                                                ...    ...    ...    ...
# 0 days 08:29:59.511000  [[121, 1], [465, 4], [561, 1]]  106.0  121.0   15.0
# 0 days 08:29:59.604000  [[121, 1], [465, 4], [561, 1]]  106.0  121.0   15.0
# 0 days 08:29:59.697000  [[465, 4], [561, 1], [608, 1]]  106.0  465.0  359.0
# 0 days 08:29:59.728000  [[465, 4], [561, 1], [608, 1]]  106.0  465.0  359.0
# 0 days 08:29:59.852000  [[465, 4], [561, 1], [608, 1]]  106.0  465.0  359.0
#
#                             m  vol_b  vol_a   dW  ...  OFI20s  OFI30s  OFI45s  \
# Timestamps                                        ...
# 0 days 00:00:00           NaN      0      0  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:01.333000    NaN      0      5  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.325000    NaN      0      3  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.387000    NaN      0      5  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.728000    NaN      0      5  NaN  ...     NaN     NaN     NaN
# ...                       ...    ...    ...  ...  ...     ...     ...     ...
# 0 days 08:29:59.511000  113.5      5      1  0.0  ...   -94.0  -100.0  -152.0
# 0 days 08:29:59.604000  113.5      5      1  0.0  ...   -94.0  -105.0  -152.0
# 0 days 08:29:59.697000  285.5      5      4  0.0  ...   -92.0  -104.0  -151.0
# 0 days 08:29:59.728000  285.5      5      4  0.0  ...   -92.0  -104.0  -151.0
# 0 days 08:29:59.852000  285.5      5      4  0.0  ...   -91.0  -104.0  -151.0
#
#                         OFI60s  signal_5s  signal_10s  signal_20s  signal_30s  \
# Timestamps
# 0 days 00:00:00            NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:01.333000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.325000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.387000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.728000     NaN        1.0         1.0         1.0         1.0
# ...                        ...        ...         ...         ...         ...
# 0 days 08:29:59.511000  -224.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.604000  -224.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.697000  -223.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.728000  -223.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.852000  -223.0        1.0         1.0         1.0         1.0
#
#                         signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0
# 0 days 00:00:01.333000         1.0         1.0
# 0 days 00:00:02.325000         1.0         1.0
# 0 days 00:00:02.387000         1.0         1.0
# 0 days 00:00:02.728000         1.0         1.0
# ...                            ...         ...
# 0 days 08:29:59.511000         1.0         1.0
# 0 days 08:29:59.604000         1.0         1.0
# 0 days 08:29:59.697000         1.0         1.0
# 0 days 08:29:59.728000         1.0         1.0
# 0 days 08:29:59.852000         1.0         1.0
#
# [317585 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 4
#                         Timestamps                                 Bids  \
# Timestamps
# 0 days 00:00:00              0.000                                   []
# 0 days 00:00:01.798000       1.798                                   []
# 0 days 00:00:02.418000       2.418                            [[75, 2]]
# 0 days 00:00:02.666000       2.666                            [[75, 2]]
# 0 days 00:00:03.069000       3.069                            [[13, 2]]
# ...                            ...                                  ...
# 0 days 08:29:59.387000   30599.387            [[51, 1], [8, 1], [4, 1]]
# 0 days 08:29:59.449000   30599.449            [[51, 1], [8, 1], [4, 1]]
# 0 days 08:29:59.728000   30599.728   [[52, 1], [51, 1], [8, 1], [4, 1]]
# 0 days 08:29:59.852000   30599.852  [[52, 1], [51, 1], [48, 1], [8, 1]]
# 0 days 08:29:59.914000   30599.914  [[77, 1], [52, 1], [51, 1], [8, 1]]
#
#                                                   Asks     b      a      s  \
# Timestamps
# 0 days 00:00:00                                     []   NaN    NaN    NaN
# 0 days 00:00:01.798000                      [[783, 5]]   NaN  783.0    NaN
# 0 days 00:00:02.418000                      [[783, 5]]  75.0  783.0  708.0
# 0 days 00:00:02.666000            [[100, 5], [783, 5]]  75.0  100.0   25.0
# 0 days 00:00:03.069000            [[100, 5], [783, 5]]  13.0  100.0   87.0
# ...                                                ...   ...    ...    ...
# 0 days 08:29:59.387000            [[413, 4], [580, 2]]  51.0  413.0  362.0
# 0 days 08:29:59.449000  [[413, 4], [580, 2], [729, 5]]  51.0  413.0  362.0
# 0 days 08:29:59.728000  [[413, 4], [580, 2], [729, 5]]  52.0  413.0  361.0
# 0 days 08:29:59.852000  [[413, 4], [580, 2], [729, 5]]  52.0  413.0  361.0
# 0 days 08:29:59.914000  [[413, 4], [580, 2], [729, 5]]  77.0  413.0  336.0
#
#                             m  vol_b  vol_a   dW  ...  OFI20s  OFI30s  OFI45s  \
# Timestamps                                        ...
# 0 days 00:00:00           NaN      0      0  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:01.798000    NaN      0      5  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.418000  429.0      2      5  NaN  ...     NaN     NaN     NaN
# 0 days 00:00:02.666000   87.5      2      5  0.0  ...    -5.0    -5.0    -5.0
# 0 days 00:00:03.069000   56.5      2      5 -2.0  ...    -7.0    -7.0    -7.0
# ...                       ...    ...    ...  ...  ...     ...     ...     ...
# 0 days 08:29:59.387000  232.0      1      4  0.0  ...   -62.0  -111.0  -164.0
# 0 days 08:29:59.449000  232.0      1      4  0.0  ...   -62.0  -113.0  -164.0
# 0 days 08:29:59.728000  232.5      1      4  1.0  ...   -61.0  -117.0  -163.0
# 0 days 08:29:59.852000  232.5      1      4  0.0  ...   -63.0  -117.0  -159.0
# 0 days 08:29:59.914000  245.0      1      4  1.0  ...   -58.0  -116.0  -158.0
#
#                         OFI60s  signal_5s  signal_10s  signal_20s  signal_30s  \
# Timestamps
# 0 days 00:00:00            NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:01.798000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.418000     NaN        1.0         1.0         1.0         1.0
# 0 days 00:00:02.666000    -5.0        1.0         1.0         2.0         2.0
# 0 days 00:00:03.069000    -7.0        1.0         1.0         2.0         2.0
# ...                        ...        ...         ...         ...         ...
# 0 days 08:29:59.387000  -306.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.449000  -306.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.728000  -300.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.852000  -300.0        1.0         1.0         1.0         1.0
# 0 days 08:29:59.914000  -299.0        1.0         1.0         1.0         1.0
#
#                         signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0
# 0 days 00:00:01.798000         1.0         1.0
# 0 days 00:00:02.418000         1.0         1.0
# 0 days 00:00:02.666000         2.0         2.0
# 0 days 00:00:03.069000         2.0         2.0
# ...                            ...         ...
# 0 days 08:29:59.387000         1.0         1.0
# 0 days 08:29:59.449000         1.0         1.0
# 0 days 08:29:59.728000         1.0         1.0
# 0 days 08:29:59.852000         1.0         1.0
# 0 days 08:29:59.914000         1.0         1.0
#
# [312419 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 5
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:00.341000       0.341
# 0 days 00:00:00.589000       0.589
# 0 days 00:00:00.899000       0.899
# 0 days 00:00:01.054000       1.054
# ...                            ...
# 0 days 08:29:59.294000   30599.294
# 0 days 08:29:59.387000   30599.387
# 0 days 08:29:59.480000   30599.480
# 0 days 08:29:59.511000   30599.511
# 0 days 08:29:59.883000   30599.883
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:00.341000                                          [[1, 11]]
# 0 days 00:00:00.589000                                          [[2, 11]]
# 0 days 00:00:00.899000                                          [[3, 11]]
# 0 days 00:00:01.054000                                          [[4, 11]]
# ...                                                                   ...
# 0 days 08:29:59.294000  [[106, 3], [104, 11], [103, 3], [102, 4], [101...
# 0 days 08:29:59.387000  [[106, 3], [104, 11], [103, 3], [102, 4], [101...
# 0 days 08:29:59.480000  [[104, 11], [103, 3], [102, 4], [101, 4], [97,...
# 0 days 08:29:59.511000  [[104, 11], [103, 3], [102, 4], [101, 4], [42,...
# 0 days 08:29:59.883000  [[104, 11], [103, 3], [102, 4], [101, 4], [42,...
#
#                                                             Asks      b  \
# Timestamps
# 0 days 00:00:00                                               []    NaN
# 0 days 00:00:00.341000                                        []    1.0
# 0 days 00:00:00.589000                                        []    2.0
# 0 days 00:00:00.899000                                        []    3.0
# 0 days 00:00:01.054000                                        []    4.0
# ...                                                          ...    ...
# 0 days 08:29:59.294000            [[174, 4], [175, 2], [673, 5]]  106.0
# 0 days 08:29:59.387000  [[173, 4], [174, 4], [175, 2], [673, 5]]  106.0
# 0 days 08:29:59.480000  [[173, 4], [174, 4], [175, 2], [673, 5]]  104.0
# 0 days 08:29:59.511000  [[173, 4], [174, 4], [175, 2], [673, 5]]  104.0
# 0 days 08:29:59.883000  [[173, 4], [174, 4], [175, 2], [673, 5]]  104.0
#
#                             a     s      m  vol_b  vol_a    dW  ...  OFI20s  \
# Timestamps                                                      ...
# 0 days 00:00:00           NaN   NaN    NaN      0      0   NaN  ...     NaN
# 0 days 00:00:00.341000    NaN   NaN    NaN     11      0   NaN  ...     NaN
# 0 days 00:00:00.589000    NaN   NaN    NaN     11      0  11.0  ...     NaN
# 0 days 00:00:00.899000    NaN   NaN    NaN     11      0  11.0  ...     NaN
# 0 days 00:00:01.054000    NaN   NaN    NaN     11      0  11.0  ...     NaN
# ...                       ...   ...    ...    ...    ...   ...  ...     ...
# 0 days 08:29:59.294000  174.0  68.0  140.0      3      4   0.0  ...   -52.0
# 0 days 08:29:59.387000  173.0  67.0  139.5      3      4   0.0  ...   -56.0
# 0 days 08:29:59.480000  173.0  69.0  138.5     11      4  -3.0  ...   -59.0
# 0 days 08:29:59.511000  173.0  69.0  138.5     11      4   0.0  ...   -59.0
# 0 days 08:29:59.883000  173.0  69.0  138.5     11      4   0.0  ...   -66.0
#
#                         OFI30s  OFI45s  OFI60s  signal_5s  signal_10s  \
# Timestamps
# 0 days 00:00:00            NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:00.341000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:00.589000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:00.899000     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:01.054000     NaN     NaN     NaN        1.0         1.0
# ...                        ...     ...     ...        ...         ...
# 0 days 08:29:59.294000   -77.0  -155.0  -234.0        1.0         1.0
# 0 days 08:29:59.387000   -81.0  -159.0  -238.0        1.0         1.0
# 0 days 08:29:59.480000   -84.0  -162.0  -241.0        1.0         1.0
# 0 days 08:29:59.511000   -84.0  -162.0  -241.0        1.0         1.0
# 0 days 08:29:59.883000   -82.0  -162.0  -240.0        1.0         1.0
#
#                         signal_20s  signal_30s  signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0         1.0         1.0
# 0 days 00:00:00.341000         1.0         1.0         1.0         1.0
# 0 days 00:00:00.589000         1.0         1.0         1.0         1.0
# 0 days 00:00:00.899000         1.0         1.0         1.0         1.0
# 0 days 00:00:01.054000         1.0         1.0         1.0         1.0
# ...                            ...         ...         ...         ...
# 0 days 08:29:59.294000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.387000         1.0         1.0         1.0         1.0
# ...
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 8
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:02.139000       2.139
# 0 days 00:00:02.232000       2.232
# 0 days 00:00:03.007000       3.007
# 0 days 00:00:03.038000       3.038
# ...                            ...
# 0 days 00:44:32.355000    2672.355
# 0 days 00:44:32.386000    2672.386
# 0 days 00:44:32.448000    2672.448
# 0 days 00:44:32.634000    2672.634
# 0 days 00:44:32.913000    2672.913
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:02.139000                                                 []
# 0 days 00:00:02.232000                                         [[108, 1]]
# 0 days 00:00:03.007000                                                 []
# 0 days 00:00:03.038000                                          [[79, 8]]
# ...                                                                   ...
# 0 days 00:44:32.355000  [[111, 2], [103, 6], [101, 6], [87, 2], [84, 8...
# 0 days 00:44:32.386000  [[111, 2], [103, 6], [101, 6], [87, 2], [84, 8...
# 0 days 00:44:32.448000  [[111, 2], [103, 6], [101, 6], [87, 2], [84, 8...
# 0 days 00:44:32.634000  [[111, 2], [103, 6], [101, 6], [84, 8], [78, 2...
# 0 days 00:44:32.913000                                                 []
#
#                                                                      Asks  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:02.139000                                         [[122, 2]]
# 0 days 00:00:02.232000                                         [[122, 2]]
# 0 days 00:00:03.007000                                         [[122, 2]]
# 0 days 00:00:03.038000                                         [[122, 2]]
# ...                                                                   ...
# 0 days 00:44:32.355000           [[113, 3], [114, 3], [117, 4], [723, 4]]
# 0 days 00:44:32.386000           [[112, 4], [113, 3], [114, 3], [723, 4]]
# 0 days 00:44:32.448000  [[112, 4], [113, 3], [114, 3], [618, 1], [723,...
# 0 days 00:44:32.634000  [[112, 4], [113, 3], [114, 3], [618, 1], [723,...
# 0 days 00:44:32.913000                                                 []
#
#                             b      a     s      m  vol_b  vol_a   dW  ...  \
# Timestamps                                                            ...
# 0 days 00:00:00           NaN    NaN   NaN    NaN      0      0  NaN  ...
# 0 days 00:00:02.139000    NaN  122.0   NaN    NaN      0      2  NaN  ...
# 0 days 00:00:02.232000  108.0  122.0  14.0  115.0      1      2  NaN  ...
# 0 days 00:00:03.007000    NaN  122.0   NaN    NaN      0      2  NaN  ...
# 0 days 00:00:03.038000   79.0  122.0  43.0  100.5      8      2  NaN  ...
# ...                       ...    ...   ...    ...    ...    ...  ...  ...
# 0 days 00:44:32.355000  111.0  113.0   2.0  112.0      2      3  0.0  ...
# 0 days 00:44:32.386000  111.0  112.0   1.0  111.5      2      4  0.0  ...
# 0 days 00:44:32.448000  111.0  112.0   1.0  111.5      2      4  0.0  ...
# 0 days 00:44:32.634000  111.0  112.0   1.0  111.5      2      4  0.0  ...
# 0 days 00:44:32.913000    NaN    NaN   NaN    NaN      0      0  NaN  ...
#
#                         OFI20s  OFI30s  OFI45s  OFI60s  signal_5s  signal_10s  \
# Timestamps
# 0 days 00:00:00            NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:02.139000     NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:02.232000     NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:03.007000     NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:03.038000     NaN     NaN     NaN     NaN        1.0         1.0
# ...                        ...     ...     ...     ...        ...         ...
# 0 days 00:44:32.355000  -205.0  -192.0  -216.0  -313.0        1.0         1.0
# 0 days 00:44:32.386000  -209.0  -196.0  -224.0  -317.0        1.0         1.0
# 0 days 00:44:32.448000  -209.0  -196.0  -224.0  -317.0        1.0         1.0
# 0 days 00:44:32.634000  -209.0  -196.0  -219.0  -313.0        1.0         1.0
# 0 days 00:44:32.913000  -210.0  -196.0  -227.0  -308.0        NaN         NaN
#
#                         signal_20s  signal_30s  signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0         1.0         1.0
# 0 days 00:00:02.139000         1.0         1.0         1.0         1.0
# 0 days 00:00:02.232000         1.0         1.0         1.0         0.0
# 0 days 00:00:03.007000         1.0         1.0         1.0         1.0
# 0 days 00:00:03.038000         1.0         1.0         1.0         1.0
# ...                            ...         ...         ...         ...
# 0 days 00:44:32.355000         1.0         1.0         1.0         1.0
# 0 days 00:44:32.386000         1.0         1.0         1.0         1.0
# 0 days 00:44:32.448000         1.0         1.0         1.0         1.0
# 0 days 00:44:32.634000         1.0         1.0         1.0         1.0
# 0 days 00:44:32.913000         NaN         NaN         NaN         NaN
#
# [27868 rows x 28 columns]
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# C:\Users\Morg\AppData\Local\Temp\ipykernel_4264\3102003276.py:50: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.lob_r[f'signal_{time}'] = self.lob_r.b.rolling(time).apply(lambda x: self.get_signal(x, self.lob_r))
# finished 9
#                         Timestamps  \
# Timestamps
# 0 days 00:00:00              0.000
# 0 days 00:00:01.054000       1.054
# 0 days 00:00:01.891000       1.891
# 0 days 00:00:02.356000       2.356
# 0 days 00:00:02.666000       2.666
# ...                            ...
# 0 days 08:29:59.697000   30599.697
# 0 days 08:29:59.759000   30599.759
# 0 days 08:29:59.821000   30599.821
# 0 days 08:29:59.883000   30599.883
# 0 days 08:29:59.976000   30599.976
#
#                                                                      Bids  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:01.054000                                           [[5, 2]]
# 0 days 00:00:01.891000                                           [[5, 2]]
# 0 days 00:00:02.356000                                           [[5, 2]]
# 0 days 00:00:02.666000                                           [[5, 2]]
# ...                                                                   ...
# 0 days 08:29:59.697000  [[107, 1], [105, 1], [103, 4], [101, 1], [100,...
# 0 days 08:29:59.759000  [[107, 1], [105, 1], [103, 4], [101, 1], [100,...
# 0 days 08:29:59.821000  [[107, 1], [105, 1], [103, 4], [101, 1], [100,...
# 0 days 08:29:59.883000  [[105, 1], [103, 4], [101, 1], [100, 4], [80, ...
# 0 days 08:29:59.976000  [[105, 3], [103, 4], [101, 1], [100, 4], [80, ...
#
#                                                                      Asks  \
# Timestamps
# 0 days 00:00:00                                                        []
# 0 days 00:00:01.054000                                                 []
# 0 days 00:00:01.891000                                         [[387, 2]]
# 0 days 00:00:02.356000                               [[386, 3], [387, 2]]
# 0 days 00:00:02.666000                      [[91, 1], [386, 3], [387, 2]]
# ...                                                                   ...
# 0 days 08:29:59.697000  [[108, 2], [109, 1], [110, 5], [229, 2], [246,...
# 0 days 08:29:59.759000  [[108, 2], [109, 1], [110, 5], [229, 2], [246,...
# 0 days 08:29:59.821000  [[108, 2], [109, 1], [110, 5], [229, 2], [246,...
# 0 days 08:29:59.883000  [[109, 1], [110, 5], [229, 2], [246, 2], [294,...
# 0 days 08:29:59.976000  [[109, 1], [110, 5], [229, 2], [246, 2], [294,...
#
#                             b      a      s      m  vol_b  vol_a   dW  ...  \
# Timestamps                                                             ...
# 0 days 00:00:00           NaN    NaN    NaN    NaN      0      0  NaN  ...
# 0 days 00:00:01.054000    5.0    NaN    NaN    NaN      2      0  NaN  ...
# 0 days 00:00:01.891000    5.0  387.0  382.0  196.0      2      2  0.0  ...
# 0 days 00:00:02.356000    5.0  386.0  381.0  195.5      2      3  0.0  ...
# 0 days 00:00:02.666000    5.0   91.0   86.0   48.0      2      1  0.0  ...
# ...                       ...    ...    ...    ...    ...    ...  ...  ...
# 0 days 08:29:59.697000  107.0  108.0    1.0  107.5      1      2  0.0  ...
# 0 days 08:29:59.759000  107.0  108.0    1.0  107.5      1      2  0.0  ...
# 0 days 08:29:59.821000  107.0  108.0    1.0  107.5      1      2  0.0  ...
# 0 days 08:29:59.883000  105.0  109.0    4.0  107.0      1      1 -1.0  ...
# 0 days 08:29:59.976000  105.0  109.0    4.0  107.0      3      1  2.0  ...
#
#                         OFI20s  OFI30s  OFI45s  OFI60s  signal_5s  signal_10s  \
# Timestamps
# 0 days 00:00:00            NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:01.054000     NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:01.891000     NaN     NaN     NaN     NaN        1.0         1.0
# 0 days 00:00:02.356000    -3.0    -3.0    -3.0    -3.0        1.0         1.0
# 0 days 00:00:02.666000    -4.0    -4.0    -4.0    -4.0        2.0         2.0
# ...                        ...     ...     ...     ...        ...         ...
# 0 days 08:29:59.697000  -136.0  -129.0  -127.0  -219.0        1.0         1.0
# 0 days 08:29:59.759000  -136.0  -126.0  -127.0  -219.0        1.0         1.0
# 0 days 08:29:59.821000  -136.0  -126.0  -127.0  -219.0        1.0         1.0
# 0 days 08:29:59.883000  -141.0  -125.0  -126.0  -218.0        1.0         1.0
# 0 days 08:29:59.976000  -133.0  -123.0  -124.0  -216.0        1.0         1.0
#
#                         signal_20s  signal_30s  signal_45s  signal_60s
# Timestamps
# 0 days 00:00:00                1.0         1.0         1.0         1.0
# 0 days 00:00:01.054000         1.0         1.0         1.0         1.0
# 0 days 00:00:01.891000         1.0         1.0         1.0         1.0
# 0 days 00:00:02.356000         1.0         1.0         1.0         1.0
# 0 days 00:00:02.666000         2.0         2.0         2.0         2.0
# ...                            ...         ...         ...         ...
# 0 days 08:29:59.697000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.759000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.821000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.883000         1.0         1.0         1.0         1.0
# 0 days 08:29:59.976000         1.0         1.0         1.0         1.0
#
# [321699 rows x 28 columns]

# %%
len(processed)
# Out:
# 10

# %%
for i, date in enumerate(dates):
    processed[i].to_csv(f'../../cleaned_data/cleaned_with_signals26-03-23/cleaned_with_signals{date}.csv')
